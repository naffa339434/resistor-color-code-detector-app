# %%
import os
import numpy as np 
import tensorflow as tf
#import tensorflow_datasets as tfds
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.8.0

# %%
path = r"C:\Users\CC\Machine_learning_projects\Resistor Color Code recognition app\BetaDataset"
os.path.exists(path)
# Out:
# True

# %%
data = tf.keras.utils.image_dataset_from_directory(path)
# Out:
# Found 1003 files belonging to 13 classes.

# %%
# splitting the data

train_size = int(len(data)* .7)
val_size = int(len(data)*.1)
test_size = int(len(data)*.2)

# %%
train = data.take(train_size) 
test = data.skip(train_size).take(test_size)
val = data.skip(train_size + test_size).take(val_size)

# %%
train_iterator = train.as_numpy_iterator()
train_iter = train_iterator.next()

# %%
axs = plt.subplots(32)
rows = 8
columns = 4
#plt.figure(figsize=(10,10))
fig = plt.figure(figsize=(20, 20))

for x in range(1,32):
  #plt.figure(figsize=(5,5)) 
  fig.add_subplot(rows,columns,x)
  plt.imshow(train_iter[0][x-1].astype(np.uint8))
  plt.title(train_iter[1][x-1])
  plt.axis('off')

# %%
IMG_SHAPE = (256, 256, 3)

# Create the base model from the pre-trained model MobileNet V2
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# ...
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\users\cc\appdata\local\programs\python\python39\lib\urllib\request.py:1342, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1341 try:
# -> 1342     h.request(req.get_method(), req.selector, req.data, headers,
#    1343               encode_chunked=req.has_header('Transfer-encoding'))
#    1344 except OSError as err: # timeout error
#
# File c:\users\cc\appdata\local\programs\python\python39\lib\http\client.py:1255, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1254 """Send a complete request to the server."""
# -> 1255 self._send_request(method, url, body, headers, encode_chunked)
#
# ...
